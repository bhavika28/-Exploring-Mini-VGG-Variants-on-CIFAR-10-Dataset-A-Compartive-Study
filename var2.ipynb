# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torchvision
import torch.utils.data
import matplotlib.pyplot as plt
import numpy as np


class MiniVGG(nn.Module):
    def __init__(self):
        super(MiniVGG, self).__init__()
        self.features = self._make_layers([
            (64, 1), (64, 2),  # First tuple: number of filters, Second tuple: stride
            (128, 1), (128, 2),
            (256, 1), (256, 2)
        ])
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 4 * 4, 512),  # Check and adjust the size based on output feature map size
            nn.ReLU(True),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3  # Start with 3 input channels for RGB images
        for num_filters, stride in cfg:
            layers += [
                nn.Conv2d(in_channels, num_filters, kernel_size=3, padding=1, stride=stride),
                nn.BatchNorm2d(num_filters),
                nn.ReLU(inplace=True)
            ]
            in_channels = num_filters  # Update in_channels for the next layer
        return nn.Sequential(*layers)

# Example usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = MiniVGG().to(device)
def load_split_train_test(datadir, valid_size=.2):
    normalize = transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    train_transforms = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
        normalize,
    ])

    test_transforms = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    train_data = datasets.CIFAR10(datadir, train=True, download=True, transform=train_transforms)
    test_data = datasets.CIFAR10(datadir, train=False, download=True, transform=test_transforms)
    
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_idx)
    valid_sampler = torch.utils.data.sampler.SubsetRandomSampler(valid_idx)

    trainloader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=64)
    validloader = torch.utils.data.DataLoader(train_data, sampler=valid_sampler, batch_size=64)
    testloader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=False)

    return trainloader, validloader, testloader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = MiniVGG().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainloader, validloader, testloader = load_split_train_test('./data', valid_size=0.1)


def train(n_epochs, patience_limit):
    valid_loss_min = np.Inf
    patience = 0  # Counter for the number of epochs without improvement
    train_losses, valid_losses = [], []
    train_accuracies, valid_accuracies = [], []
    
    for epoch in range(1, n_epochs+1):
        train_loss = 0.0
        valid_loss = 0.0
        correct = 0
        total = 0
        
        net.train()
        for data, target in trainloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = net(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * data.size(0)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
        train_accuracy = 100 * correct / total
        train_losses.append(train_loss / len(trainloader.sampler))
        train_accuracies.append(train_accuracy)
        
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in validloader:
                data, target = data.to(device), target.to(device)
                output = net(data)
                loss = criterion(output, target)
                valid_loss += loss.item() * data.size(0)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
                
        valid_accuracy = 100 * correct / total
        valid_losses.append(valid_loss / len(validloader.sampler))
        valid_accuracies.append(valid_accuracy)
        
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tTraining Accuracy: {:.2f}% \tValidation Accuracy: {:.2f}%'.format(
            epoch, train_loss / len(trainloader.sampler), valid_loss / len(validloader.sampler),
            train_accuracy, valid_accuracy))
        
        # Check if the validation loss has decreased
        if valid_loss < valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(net.state_dict(), 'model_cifar.pt')
            valid_loss_min = valid_loss
            patience = 0  # Reset patience since we have an improvement
        else:
            patience += 1  # Increment the patience counter
            print(f'Patience for {patience} epochs.')
            if patience >= patience_limit:
                print('Early stopping triggered.')
                break
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# Example usage
patience_limit = 5  # Number of epochs to tolerate no improvement
train_losses, valid_losses, train_accuracies, valid_accuracies = train(50, patience_limit)


# Plotting the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# Test the model with test data
def test():
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))

test()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1 	Training Loss: 1.553191 	Validation Loss: 1.407207 	Training Accuracy: 43.12% 	Validation Accuracy: 48.58%
# Validation loss decreased (inf --> 7036.037411). Saving model ...
# Epoch: 2 	Training Loss: 1.234183 	Validation Loss: 1.106831 	Training Accuracy: 55.92% 	Validation Accuracy: 60.74%
# Validation loss decreased (7036.037411 --> 5534.154435). Saving model ...
# Epoch: 3 	Training Loss: 1.048914 	Validation Loss: 0.998588 	Training Accuracy: 62.79% 	Validation Accuracy: 64.82%
# Validation loss decreased (5534.154435 --> 4992.941964). Saving model ...
# Epoch: 4 	Training Loss: 0.934517 	Validation Loss: 0.877137 	Training Accuracy: 67.01% 	Validation Accuracy: 69.46%
# Validation loss decreased (4992.941964 --> 4385.686531). Saving model ...
# Epoch: 5 	Training Loss: 0.848003 	Validation Loss: 0.819112 	Training Accuracy: 70.01% 	Validation Accuracy: 70.66%
# Validation loss decreased (4385.686531 --> 4095.562355). Saving model ...
# Epoch: 6 	Training Loss: 0.780982 	Validation Loss: 0.765057 	Training Accuracy: 72.63% 	Validation Accuracy: 73.70%
# Validation loss decreased (4095.562355 --> 3825.283607). Saving model ...
# Epoch: 7 	Training Loss: 0.733489 	Validation Loss: 0.734099 	Training Accuracy: 74.29% 	Validation Accuracy: 74.44%
# Patience for 2 epochs.
# Epoch: 27 	Training Loss: 0.359399 	Validation Loss: 0.483252 	Training Accuracy: 87.35% 	Validation Accuracy: 84.10%
# Validation loss decreased (2514.673772 --> 2416.257812). Saving model ...
# Epoch: 28 	Training Loss: 0.344785 	Validation Loss: 0.504347 	Training Accuracy: 87.80% 	Validation Accuracy: 83.32%
# Patience for 1 epochs.
# Epoch: 29 	Training Loss: 0.344069 	Validation Loss: 0.487255 	Training Accuracy: 87.77% 	Validation Accuracy: 83.78%
# Patience for 2 epochs.
# Epoch: 30 	Training Loss: 0.334800 	Validation Loss: 0.494574 	Training Accuracy: 88.05% 	Validation Accuracy: 83.26%
# Patience for 3 epochs.
# Epoch: 31 	Training Loss: 0.320667 	Validation Loss: 0.478735 	Training Accuracy: 88.73% 	Validation Accuracy: 84.06%
# Validation loss decreased (2416.257812 --> 2393.673298). Saving model ...
# Epoch: 32 	Training Loss: 0.318060 	Validation Loss: 0.481473 	Training Accuracy: 88.78% 	Validation Accuracy: 84.30%
# Patience for 1 epochs.
# Epoch: 33 	Training Loss: 0.311577 	Validation Loss: 0.504786 	Training Accuracy: 88.90% 	Validation Accuracy: 82.82%
# Patience for 2 epochs.
# Epoch: 34 	Training Loss: 0.303172 	Validation Loss: 0.531381 	Training Accuracy: 89.08% 	Validation Accuracy: 82.90%
# Patience for 3 epochs.
# Epoch: 35 	Training Loss: 0.298961 	Validation Loss: 0.503567 	Training Accuracy: 89.37% 	Validation Accuracy: 83.28%
# Patience for 4 epochs.
# Epoch: 36 	Training Loss: 0.293827 	Validation Loss: 0.476952 	Training Accuracy: 89.66% 	Validation Accuracy: 84.06%
# Validation loss decreased (2393.673298 --> 2384.759614). Saving model ...
# Epoch: 37 	Training Loss: 0.283653 	Validation Loss: 0.485248 	Training Accuracy: 90.02% 	Validation Accuracy: 84.14%
# Patience for 1 epochs.
# Epoch: 38 	Training Loss: 0.278556 	Validation Loss: 0.494974 	Training Accuracy: 90.17% 	Validation Accuracy: 83.98%
# Patience for 2 epochs.
# Epoch: 39 	Training Loss: 0.268939 	Validation Loss: 0.489349 	Training Accuracy: 90.41% 	Validation Accuracy: 84.66%
# Patience for 3 epochs.
# Epoch: 40 	Training Loss: 0.270737 	Validation Loss: 0.464942 	Training Accuracy: 90.30% 	Validation Accuracy: 85.18%
# Validation loss decreased (2384.759614 --> 2324.707557). Saving model ...
# Epoch: 41 	Training Loss: 0.262390 	Validation Loss: 0.457339 	Training Accuracy: 90.60% 	Validation Accuracy: 84.78%
# Validation loss decreased (2324.707557 --> 2286.694980). Saving model ...
# Epoch: 42 	Training Loss: 0.257893 	Validation Loss: 0.482164 	Training Accuracy: 90.94% 	Validation Accuracy: 84.80%
# Patience for 1 epochs.
# Epoch: 43 	Training Loss: 0.251809 	Validation Loss: 0.483566 	Training Accuracy: 91.14% 	Validation Accuracy: 84.70%
# Patience for 2 epochs.
# Epoch: 44 	Training Loss: 0.250181 	Validation Loss: 0.478272 	Training Accuracy: 91.07% 	Validation Accuracy: 84.10%
# Patience for 3 epochs.
# Epoch: 45 	Training Loss: 0.246212 	Validation Loss: 0.483543 	Training Accuracy: 91.17% 	Validation Accuracy: 84.46%
# Patience for 4 epochs.
# Epoch: 46 	Training Loss: 0.243770 	Validation Loss: 0.480605 	Training Accuracy: 91.42% 	Validation Accuracy: 84.74%
# Patience for 5 epochs.
# Early stopping triggered.
# Accuracy of the network on the 10000 test images: 87 %
