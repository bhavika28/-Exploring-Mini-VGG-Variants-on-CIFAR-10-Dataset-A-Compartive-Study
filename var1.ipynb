# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torchvision
import torch.utils.data
import matplotlib.pyplot as plt
import numpy as np

class MiniVGG(nn.Module):
    def __init__(self):
        super(MiniVGG, self).__init__()
        self.features = self._make_layers([64, 64, 'M', 128, 128, 'M', 256, 256, 'M'])
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 4 * 4, 512),
            nn.SELU(True),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.ReLU(inplace=True)]
                in_channels = x
        return nn.Sequential(*layers)

def load_split_train_test(datadir, valid_size=.2):
    normalize = transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    train_transforms = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
        normalize,
    ])

    test_transforms = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    train_data = datasets.CIFAR10(datadir, train=True, download=True, transform=train_transforms)
    test_data = datasets.CIFAR10(datadir, train=False, download=True, transform=test_transforms)
    
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_idx)
    valid_sampler = torch.utils.data.sampler.SubsetRandomSampler(valid_idx)

    trainloader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=64)
    validloader = torch.utils.data.DataLoader(train_data, sampler=valid_sampler, batch_size=64)
    testloader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=False)

    return trainloader, validloader, testloader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = MiniVGG().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainloader, validloader, testloader = load_split_train_test('./data', valid_size=0.1)


def train(n_epochs, patience_limit):
    valid_loss_min = np.Inf
    patience = 0  # Counter for the number of epochs without improvement
    train_losses, valid_losses = [], []
    train_accuracies, valid_accuracies = [], []
    
    for epoch in range(1, n_epochs+1):
        train_loss = 0.0
        valid_loss = 0.0
        correct = 0
        total = 0
        
        net.train()
        for data, target in trainloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = net(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * data.size(0)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
        train_accuracy = 100 * correct / total
        train_losses.append(train_loss / len(trainloader.sampler))
        train_accuracies.append(train_accuracy)
        
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in validloader:
                data, target = data.to(device), target.to(device)
                output = net(data)
                loss = criterion(output, target)
                valid_loss += loss.item() * data.size(0)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
                
        valid_accuracy = 100 * correct / total
        valid_losses.append(valid_loss / len(validloader.sampler))
        valid_accuracies.append(valid_accuracy)
        
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tTraining Accuracy: {:.2f}% \tValidation Accuracy: {:.2f}%'.format(
            epoch, train_loss / len(trainloader.sampler), valid_loss / len(validloader.sampler),
            train_accuracy, valid_accuracy))
        
        # Check if the validation loss has decreased
        if valid_loss < valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(net.state_dict(), 'model_cifar.pt')
            valid_loss_min = valid_loss
            patience = 0  # Reset patience since we have an improvement
        else:
            patience += 1  # Increment the patience counter
            print(f'Patience for {patience} epochs.')
            if patience >= patience_limit:
                print('Early stopping triggered.')
                break
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# Example usage
patience_limit = 5  # Number of epochs to tolerate no improvement
train_losses, valid_losses, train_accuracies, valid_accuracies = train(50, patience_limit)


# Plotting the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# Test the model with test data
def test():
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))

test()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1 	Training Loss: 1.862491 	Validation Loss: 1.583070 	Training Accuracy: 30.74% 	Validation Accuracy: 41.94%
# Validation loss decreased (inf --> 7915.348252). Saving model ...
# Epoch: 2 	Training Loss: 1.411300 	Validation Loss: 1.330470 	Training Accuracy: 48.51% 	Validation Accuracy: 53.54%
# Validation loss decreased (7915.348252 --> 6652.349641). Saving model ...
# Epoch: 3 	Training Loss: 1.169185 	Validation Loss: 1.025012 	Training Accuracy: 58.18% 	Validation Accuracy: 63.52%
# Validation loss decreased (6652.349641 --> 5125.061639). Saving model ...
# Epoch: 4 	Training Loss: 1.007554 	Validation Loss: 0.977247 	Training Accuracy: 64.60% 	Validation Accuracy: 65.32%
# Validation loss decreased (5125.061639 --> 4886.236346). Saving model ...
# Epoch: 5 	Training Loss: 0.911392 	Validation Loss: 0.872401 	Training Accuracy: 67.74% 	Validation Accuracy: 69.24%
# Validation loss decreased (4886.236346 --> 4362.003332). Saving model ...
# Epoch: 6 	Training Loss: 0.839730 	Validation Loss: 0.832388 	Training Accuracy: 70.62% 	Validation Accuracy: 71.40%
# Validation loss decreased (4362.003332 --> 4161.938200). Saving model ...
# Epoch: 7 	Training Loss: 0.784921 	Validation Loss: 0.764202 	Training Accuracy: 72.63% 	Validation Accuracy: 73.18%
# Validation loss decreased (4161.938200 --> 3821.010908). Saving model ...
# Epoch: 8 	Training Loss: 0.740678 	Validation Loss: 0.716666 	Training Accuracy: 74.36% 	Validation Accuracy: 74.82%
# Validation loss decreased (3821.010908 --> 3583.332123). Saving model ...
# Epoch: 9 	Training Loss: 0.703218 	Validation Loss: 0.722500 	Training Accuracy: 75.38% 	Validation Accuracy: 74.22%
# Patience for 1 epochs.
# Epoch: 10 	Training Loss: 0.671382 	Validation Loss: 0.689547 	Training Accuracy: 76.54% 	Validation Accuracy: 75.84%
# Validation loss decreased (3583.332123 --> 3447.733651). Saving model ...
# Epoch: 11 	Training Loss: 0.640366 	Validation Loss: 0.680076 	Training Accuracy: 77.74% 	Validation Accuracy: 76.06%
# Validation loss decreased (3447.733651 --> 3400.380665). Saving model ...
# Epoch: 12 	Training Loss: 0.627931 	Validation Loss: 0.609631 	Training Accuracy: 78.22% 	Validation Accuracy: 78.68%
# Validation loss decreased (3400.380665 --> 3048.157004). Saving model ...
# Epoch: 13 	Training Loss: 0.594019 	Validation Loss: 0.649853 	Training Accuracy: 79.41% 	Validation Accuracy: 77.32%
# Patience for 1 epochs.
# Epoch: 14 	Training Loss: 0.586691 	Validation Loss: 0.649225 	Training Accuracy: 79.39% 	Validation Accuracy: 77.72%
# Patience for 2 epochs.
# Epoch: 15 	Training Loss: 0.565349 	Validation Loss: 0.611695 	Training Accuracy: 80.37% 	Validation Accuracy: 78.98%
# Patience for 3 epochs.
# Epoch: 16 	Training Loss: 0.549175 	Validation Loss: 0.611389 	Training Accuracy: 80.75% 	Validation Accuracy: 78.82%
# Patience for 4 epochs.
# Epoch: 17 	Training Loss: 0.532484 	Validation Loss: 0.562122 	Training Accuracy: 81.53% 	Validation Accuracy: 81.14%
# Validation loss decreased (3048.157004 --> 2810.611137). Saving model ...
# Epoch: 18 	Training Loss: 0.520234 	Validation Loss: 0.555173 	Training Accuracy: 81.80% 	Validation Accuracy: 81.00%
# Validation loss decreased (2810.611137 --> 2775.866493). Saving model ...
# Epoch: 19 	Training Loss: 0.508537 	Validation Loss: 0.591768 	Training Accuracy: 82.46% 	Validation Accuracy: 81.06%
# Patience for 1 epochs.
# Epoch: 20 	Training Loss: 0.497210 	Validation Loss: 0.536212 	Training Accuracy: 82.62% 	Validation Accuracy: 81.20%
# Validation loss decreased (2775.866493 --> 2681.057576). Saving model ...
# Epoch: 21 	Training Loss: 0.489816 	Validation Loss: 0.600128 	Training Accuracy: 82.93% 	Validation Accuracy: 79.24%
# Patience for 1 epochs.
# Epoch: 22 	Training Loss: 0.483906 	Validation Loss: 0.544517 	Training Accuracy: 83.20% 	Validation Accuracy: 81.00%
# Patience for 2 epochs.
# Epoch: 23 	Training Loss: 0.469577 	Validation Loss: 0.552941 	Training Accuracy: 83.74% 	Validation Accuracy: 81.52%
# Patience for 3 epochs.
# Epoch: 24 	Training Loss: 0.470025 	Validation Loss: 0.534917 	Training Accuracy: 83.91% 	Validation Accuracy: 81.86%
# Validation loss decreased (2681.057576 --> 2674.585602). Saving model ...
# Epoch: 25 	Training Loss: 0.458810 	Validation Loss: 0.524173 	Training Accuracy: 83.97% 	Validation Accuracy: 82.00%
# Validation loss decreased (2674.585602 --> 2620.864628). Saving model ...
# Epoch: 26 	Training Loss: 0.444891 	Validation Loss: 0.503724 	Training Accuracy: 84.46% 	Validation Accuracy: 82.08%
# Validation loss decreased (2620.864628 --> 2518.622100). Saving model ...
# Epoch: 27 	Training Loss: 0.449157 	Validation Loss: 0.535047 	Training Accuracy: 84.42% 	Validation Accuracy: 81.54%
# Patience for 1 epochs.
# Epoch: 28 	Training Loss: 0.436090 	Validation Loss: 0.527827 	Training Accuracy: 84.86% 	Validation Accuracy: 82.62%
# Patience for 2 epochs.
# Epoch: 29 	Training Loss: 0.426948 	Validation Loss: 0.512852 	Training Accuracy: 85.19% 	Validation Accuracy: 82.80%
# Patience for 3 epochs.
# Epoch: 30 	Training Loss: 0.424825 	Validation Loss: 0.522750 	Training Accuracy: 85.12% 	Validation Accuracy: 82.04%
# Patience for 4 epochs.
# Epoch: 31 	Training Loss: 0.414653 	Validation Loss: 0.518883 	Training Accuracy: 85.60% 	Validation Accuracy: 82.70%
# Patience for 5 epochs.
# Early stopping triggered.
# Accuracy of the network on the 10000 test images: 86 %

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torchvision
import torch.utils.data
import matplotlib.pyplot as plt
import numpy as np

class MiniVGG(nn.Module):
    def __init__(self):
        super(MiniVGG, self).__init__()
        self.features = self._make_layers([64, 64, 'M', 128, 128, 'M', 256, 256, 'M'])
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 4 * 4, 512),
            nn.SiLU(True),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.ReLU(inplace=True)]
                in_channels = x
        return nn.Sequential(*layers)

def load_split_train_test(datadir, valid_size=.2):
    normalize = transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    train_transforms = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
        normalize,
    ])

    test_transforms = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    train_data = datasets.CIFAR10(datadir, train=True, download=True, transform=train_transforms)
    test_data = datasets.CIFAR10(datadir, train=False, download=True, transform=test_transforms)
    
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_idx)
    valid_sampler = torch.utils.data.sampler.SubsetRandomSampler(valid_idx)

    trainloader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=64)
    validloader = torch.utils.data.DataLoader(train_data, sampler=valid_sampler, batch_size=64)
    testloader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=False)

    return trainloader, validloader, testloader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = MiniVGG().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainloader, validloader, testloader = load_split_train_test('./data', valid_size=0.1)


def train(n_epochs, patience_limit):
    valid_loss_min = np.Inf
    patience = 0  # Counter for the number of epochs without improvement
    train_losses, valid_losses = [], []
    train_accuracies, valid_accuracies = [], []
    
    for epoch in range(1, n_epochs+1):
        train_loss = 0.0
        valid_loss = 0.0
        correct = 0
        total = 0
        
        net.train()
        for data, target in trainloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = net(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * data.size(0)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
        train_accuracy = 100 * correct / total
        train_losses.append(train_loss / len(trainloader.sampler))
        train_accuracies.append(train_accuracy)
        
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in validloader:
                data, target = data.to(device), target.to(device)
                output = net(data)
                loss = criterion(output, target)
                valid_loss += loss.item() * data.size(0)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
                
        valid_accuracy = 100 * correct / total
        valid_losses.append(valid_loss / len(validloader.sampler))
        valid_accuracies.append(valid_accuracy)
        
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tTraining Accuracy: {:.2f}% \tValidation Accuracy: {:.2f}%'.format(
            epoch, train_loss / len(trainloader.sampler), valid_loss / len(validloader.sampler),
            train_accuracy, valid_accuracy))
        
        # Check if the validation loss has decreased
        if valid_loss < valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(net.state_dict(), 'model_cifar.pt')
            valid_loss_min = valid_loss
            patience = 0  # Reset patience since we have an improvement
        else:
            patience += 1  # Increment the patience counter
            print(f'Patience for {patience} epochs.')
            if patience >= patience_limit:
                print('Early stopping triggered.')
                break
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# Example usage
patience_limit = 5  # Number of epochs to tolerate no improvement
train_losses, valid_losses, train_accuracies, valid_accuracies = train(50, patience_limit)


# Plotting the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# Test the model with test data
def test():
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))

test()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1 	Training Loss: 2.045808 	Validation Loss: 1.696181 	Training Accuracy: 23.33% 	Validation Accuracy: 37.34%
# Validation loss decreased (inf --> 8480.905940). Saving model ...
# Epoch: 2 	Training Loss: 1.547480 	Validation Loss: 1.349856 	Training Accuracy: 43.46% 	Validation Accuracy: 50.12%
# Validation loss decreased (8480.905940 --> 6749.279273). Saving model ...
# Epoch: 3 	Training Loss: 1.298220 	Validation Loss: 1.320183 	Training Accuracy: 53.33% 	Validation Accuracy: 51.76%
# Validation loss decreased (6749.279273 --> 6600.916714). Saving model ...
# Epoch: 4 	Training Loss: 1.125410 	Validation Loss: 1.038325 	Training Accuracy: 59.62% 	Validation Accuracy: 62.48%
# Validation loss decreased (6600.916714 --> 5191.624291). Saving model ...
# Epoch: 5 	Training Loss: 1.004049 	Validation Loss: 0.905361 	Training Accuracy: 64.28% 	Validation Accuracy: 68.18%
# Validation loss decreased (5191.624291 --> 4526.807351). Saving model ...
# Epoch: 6 	Training Loss: 0.903951 	Validation Loss: 0.886659 	Training Accuracy: 68.17% 	Validation Accuracy: 69.12%
# Validation loss decreased (4526.807351 --> 4433.293895). Saving model ...
# Epoch: 7 	Training Loss: 0.831199 	Validation Loss: 0.791495 	Training Accuracy: 70.69% 	Validation Accuracy: 72.52%
# Validation loss decreased (4433.293895 --> 3957.474904). Saving model ...
# Epoch: 8 	Training Loss: 0.780739 	Validation Loss: 0.693468 	Training Accuracy: 72.43% 	Validation Accuracy: 76.00%
# Validation loss decreased (3957.474904 --> 3467.341795). Saving model ...
# Epoch: 9 	Training Loss: 0.733932 	Validation Loss: 0.688204 	Training Accuracy: 74.39% 	Validation Accuracy: 76.12%
# Validation loss decreased (3467.341795 --> 3441.018637). Saving model ...
# Epoch: 10 	Training Loss: 0.691102 	Validation Loss: 0.652366 	Training Accuracy: 75.96% 	Validation Accuracy: 76.98%
# Validation loss decreased (3441.018637 --> 3261.830219). Saving model ...
# Epoch: 11 	Training Loss: 0.662550 	Validation Loss: 0.683022 	Training Accuracy: 76.93% 	Validation Accuracy: 76.82%
# Patience for 1 epochs.
# Epoch: 12 	Training Loss: 0.630326 	Validation Loss: 0.653317 	Training Accuracy: 77.87% 	Validation Accuracy: 77.14%
# Patience for 2 epochs.
# Epoch: 13 	Training Loss: 0.604309 	Validation Loss: 0.588661 	Training Accuracy: 78.64% 	Validation Accuracy: 79.66%
# Validation loss decreased (3261.830219 --> 2943.306581). Saving model ...
# Epoch: 14 	Training Loss: 0.569931 	Validation Loss: 0.581787 	Training Accuracy: 79.94% 	Validation Accuracy: 80.22%
# Validation loss decreased (2943.306581 --> 2908.932942). Saving model ...
# Epoch: 15 	Training Loss: 0.559346 	Validation Loss: 0.545411 	Training Accuracy: 80.34% 	Validation Accuracy: 81.30%
# Validation loss decreased (2908.932942 --> 2727.053092). Saving model ...
# Epoch: 16 	Training Loss: 0.532057 	Validation Loss: 0.591147 	Training Accuracy: 81.43% 	Validation Accuracy: 78.86%
# Patience for 1 epochs.
# Epoch: 17 	Training Loss: 0.516237 	Validation Loss: 0.550972 	Training Accuracy: 81.90% 	Validation Accuracy: 81.12%
# Patience for 2 epochs.
# Epoch: 18 	Training Loss: 0.502934 	Validation Loss: 0.531884 	Training Accuracy: 82.31% 	Validation Accuracy: 82.02%
# Validation loss decreased (2727.053092 --> 2659.419235). Saving model ...
# Epoch: 19 	Training Loss: 0.486274 	Validation Loss: 0.529372 	Training Accuracy: 82.95% 	Validation Accuracy: 81.62%
# Validation loss decreased (2659.419235 --> 2646.858112). Saving model ...
# Epoch: 20 	Training Loss: 0.476763 	Validation Loss: 0.544148 	Training Accuracy: 83.35% 	Validation Accuracy: 81.52%
# Patience for 1 epochs.
# Epoch: 21 	Training Loss: 0.468867 	Validation Loss: 0.485345 	Training Accuracy: 83.60% 	Validation Accuracy: 82.82%
# Validation loss decreased (2646.858112 --> 2426.726641). Saving model ...
# Epoch: 22 	Training Loss: 0.448376 	Validation Loss: 0.490376 	Training Accuracy: 84.24% 	Validation Accuracy: 83.28%
# Patience for 1 epochs.
# Epoch: 23 	Training Loss: 0.436730 	Validation Loss: 0.495158 	Training Accuracy: 84.62% 	Validation Accuracy: 82.88%
# Patience for 2 epochs.
# Epoch: 24 	Training Loss: 0.427110 	Validation Loss: 0.471637 	Training Accuracy: 85.03% 	Validation Accuracy: 83.94%
# Validation loss decreased (2426.726641 --> 2358.183205). Saving model ...
# Epoch: 25 	Training Loss: 0.414110 	Validation Loss: 0.488000 	Training Accuracy: 85.56% 	Validation Accuracy: 83.58%
# Patience for 1 epochs.
# Epoch: 26 	Training Loss: 0.412090 	Validation Loss: 0.482147 	Training Accuracy: 85.72% 	Validation Accuracy: 83.36%
# Patience for 2 epochs.
# Epoch: 27 	Training Loss: 0.398434 	Validation Loss: 0.455703 	Training Accuracy: 86.04% 	Validation Accuracy: 83.96%
# Validation loss decreased (2358.183205 --> 2278.515296). Saving model ...
# Epoch: 28 	Training Loss: 0.389447 	Validation Loss: 0.472147 	Training Accuracy: 86.20% 	Validation Accuracy: 84.06%
# Patience for 1 epochs.
# Epoch: 29 	Training Loss: 0.386881 	Validation Loss: 0.497510 	Training Accuracy: 86.43% 	Validation Accuracy: 82.88%
# Patience for 2 epochs.
# Epoch: 30 	Training Loss: 0.378414 	Validation Loss: 0.445813 	Training Accuracy: 86.91% 	Validation Accuracy: 84.92%
# Validation loss decreased (2278.515296 --> 2229.065313). Saving model ...
# Epoch: 31 	Training Loss: 0.371297 	Validation Loss: 0.466615 	Training Accuracy: 86.98% 	Validation Accuracy: 84.14%
# Patience for 1 epochs.
# Epoch: 32 	Training Loss: 0.367849 	Validation Loss: 0.449597 	Training Accuracy: 87.17% 	Validation Accuracy: 84.46%
# Patience for 2 epochs.
# Epoch: 33 	Training Loss: 0.364195 	Validation Loss: 0.482165 	Training Accuracy: 87.23% 	Validation Accuracy: 83.36%
# Patience for 3 epochs.
# Epoch: 34 	Training Loss: 0.348147 	Validation Loss: 0.454969 	Training Accuracy: 88.03% 	Validation Accuracy: 84.42%
# Patience for 4 epochs.
# Epoch: 35 	Training Loss: 0.345240 	Validation Loss: 0.454397 	Training Accuracy: 88.06% 	Validation Accuracy: 84.48%
# Patience for 5 epochs.
# Early stopping triggered.
# Accuracy of the network on the 10000 test images: 87 %
