# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torchvision
import torch.utils.data
import matplotlib.pyplot as plt
import numpy as np

class MiniVGG_DropoutAfterConv(nn.Module):
    def __init__(self):
        super(MiniVGG_DropoutAfterConv, self).__init__()
        self.features = self._make_layers([64, 64, 'M', 128, 128, 'M', 256, 256, 'M'], dropout=True)
        self.classifier = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512),
            nn.ReLU(True),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _make_layers(self, cfg, dropout=False):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
                if dropout:
                    layers += [nn.Dropout(0.25)]
        return nn.Sequential(*layers)

class MiniVGG_DropoutBeforeFC(nn.Module):
    def __init__(self):
        super(MiniVGG_DropoutBeforeFC, self).__init__()
        self.features = self._make_layers([64, 64, 'M', 128, 128, 'M', 256, 256, 'M'])
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 4 * 4, 512),
            nn.ReLU(True),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        return nn.Sequential(*layers)

# %%
def load_split_train_test(datadir, valid_size=.2):
    normalize = transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    train_transforms = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
        normalize,
    ])

    test_transforms = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    train_data = datasets.CIFAR10(datadir, train=True, download=True, transform=train_transforms)
    test_data = datasets.CIFAR10(datadir, train=False, download=True, transform=test_transforms)
    
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_idx)
    valid_sampler = torch.utils.data.sampler.SubsetRandomSampler(valid_idx)

    trainloader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=64)
    validloader = torch.utils.data.DataLoader(train_data, sampler=valid_sampler, batch_size=64)
    testloader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=False)

    return trainloader, validloader, testloader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = MiniVGG_DropoutAfterConv().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainloader, validloader, testloader = load_split_train_test('./data', valid_size=0.1)


def train(n_epochs, patience_limit):
    valid_loss_min = np.Inf
    patience = 0  # Counter for the number of epochs without improvement
    train_losses, valid_losses = [], []
    train_accuracies, valid_accuracies = [], []
    
    for epoch in range(1, n_epochs+1):
        train_loss = 0.0
        valid_loss = 0.0
        correct = 0
        total = 0
        
        net.train()
        for data, target in trainloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = net(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * data.size(0)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
        train_accuracy = 100 * correct / total
        train_losses.append(train_loss / len(trainloader.sampler))
        train_accuracies.append(train_accuracy)
        
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in validloader:
                data, target = data.to(device), target.to(device)
                output = net(data)
                loss = criterion(output, target)
                valid_loss += loss.item() * data.size(0)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
                
        valid_accuracy = 100 * correct / total
        valid_losses.append(valid_loss / len(validloader.sampler))
        valid_accuracies.append(valid_accuracy)
        
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tTraining Accuracy: {:.2f}% \tValidation Accuracy: {:.2f}%'.format(
            epoch, train_loss / len(trainloader.sampler), valid_loss / len(validloader.sampler),
            train_accuracy, valid_accuracy))
        
        # Check if the validation loss has decreased
        if valid_loss < valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(net.state_dict(), 'model_cifar.pt')
            valid_loss_min = valid_loss
            patience = 0  # Reset patience since we have an improvement
        else:
            patience += 1  # Increment the patience counter
            print(f'Patience for {patience} epochs.')
            if patience >= patience_limit:
                print('Early stopping triggered.')
                break
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# Example usage
patience_limit = 5  # Number of epochs to tolerate no improvement
train_losses, valid_losses, train_accuracies, valid_accuracies = train(50, patience_limit)


# Plotting the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# Test the model with test data
def test():
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))

test()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1 	Training Loss: 1.591657 	Validation Loss: 1.624591 	Training Accuracy: 41.60% 	Validation Accuracy: 39.62%
# Validation loss decreased (inf --> 8122.953283). Saving model ...
# Epoch: 2 	Training Loss: 1.247538 	Validation Loss: 1.350530 	Training Accuracy: 55.64% 	Validation Accuracy: 53.92%
# Validation loss decreased (8122.953283 --> 6752.650970). Saving model ...
# Epoch: 3 	Training Loss: 1.048229 	Validation Loss: 1.439680 	Training Accuracy: 63.17% 	Validation Accuracy: 50.60%
# Patience for 1 epochs.
# Epoch: 4 	Training Loss: 0.944591 	Validation Loss: 1.220206 	Training Accuracy: 67.16% 	Validation Accuracy: 57.20%
# Validation loss decreased (6752.650970 --> 6101.027744). Saving model ...
# Epoch: 5 	Training Loss: 0.858500 	Validation Loss: 1.070634 	Training Accuracy: 70.03% 	Validation Accuracy: 63.46%
# Patience for 2 epochs.
# Epoch: 23 	Training Loss: 0.406469 	Validation Loss: 0.617382 	Training Accuracy: 85.85% 	Validation Accuracy: 78.44%
# Validation loss decreased (3181.869940 --> 3086.912124). Saving model ...
# Epoch: 24 	Training Loss: 0.401274 	Validation Loss: 0.558990 	Training Accuracy: 85.84% 	Validation Accuracy: 80.94%
# Validation loss decreased (3086.912124 --> 2794.947932). Saving model ...
# Epoch: 25 	Training Loss: 0.388863 	Validation Loss: 0.646231 	Training Accuracy: 86.42% 	Validation Accuracy: 78.06%
# Patience for 1 epochs.
# Epoch: 26 	Training Loss: 0.382094 	Validation Loss: 0.537046 	Training Accuracy: 86.48% 	Validation Accuracy: 81.96%
# Validation loss decreased (2794.947932 --> 2685.230577). Saving model ...
# Epoch: 27 	Training Loss: 0.365307 	Validation Loss: 0.640544 	Training Accuracy: 87.29% 	Validation Accuracy: 77.64%
# Patience for 1 epochs.
# Epoch: 28 	Training Loss: 0.357679 	Validation Loss: 0.580237 	Training Accuracy: 87.46% 	Validation Accuracy: 81.22%
# Patience for 2 epochs.
# Epoch: 29 	Training Loss: 0.353336 	Validation Loss: 0.540768 	Training Accuracy: 87.61% 	Validation Accuracy: 81.38%
# Patience for 3 epochs.
# Epoch: 30 	Training Loss: 0.341935 	Validation Loss: 0.513374 	Training Accuracy: 87.74% 	Validation Accuracy: 82.40%
# Validation loss decreased (2685.230577 --> 2566.869162). Saving model ...
# Epoch: 31 	Training Loss: 0.334102 	Validation Loss: 0.510118 	Training Accuracy: 88.22% 	Validation Accuracy: 82.76%
# Validation loss decreased (2566.869162 --> 2550.591142). Saving model ...
# Epoch: 32 	Training Loss: 0.334779 	Validation Loss: 0.539397 	Training Accuracy: 88.35% 	Validation Accuracy: 81.68%
# Patience for 1 epochs.
# Epoch: 33 	Training Loss: 0.318415 	Validation Loss: 0.521910 	Training Accuracy: 88.87% 	Validation Accuracy: 82.22%
# Patience for 2 epochs.
# Epoch: 34 	Training Loss: 0.320603 	Validation Loss: 0.497173 	Training Accuracy: 88.53% 	Validation Accuracy: 82.68%
# Validation loss decreased (2550.591142 --> 2485.865375). Saving model ...
# Epoch: 35 	Training Loss: 0.306140 	Validation Loss: 0.519027 	Training Accuracy: 89.14% 	Validation Accuracy: 82.44%
# Patience for 1 epochs.
# Epoch: 36 	Training Loss: 0.300875 	Validation Loss: 0.525221 	Training Accuracy: 89.43% 	Validation Accuracy: 82.28%
# Patience for 2 epochs.
# Epoch: 37 	Training Loss: 0.294486 	Validation Loss: 0.579686 	Training Accuracy: 89.65% 	Validation Accuracy: 80.54%
# Patience for 3 epochs.
# Epoch: 38 	Training Loss: 0.294464 	Validation Loss: 0.552965 	Training Accuracy: 89.70% 	Validation Accuracy: 81.48%
# Patience for 4 epochs.
# Epoch: 39 	Training Loss: 0.284873 	Validation Loss: 0.551966 	Training Accuracy: 89.92% 	Validation Accuracy: 81.96%
# Patience for 5 epochs.
# Early stopping triggered.
# Accuracy of the network on the 10000 test images: 86 %

# %%
def load_split_train_test(datadir, valid_size=.2):
    normalize = transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    train_transforms = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
        normalize,
    ])

    test_transforms = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    train_data = datasets.CIFAR10(datadir, train=True, download=True, transform=train_transforms)
    test_data = datasets.CIFAR10(datadir, train=False, download=True, transform=test_transforms)
    
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_idx)
    valid_sampler = torch.utils.data.sampler.SubsetRandomSampler(valid_idx)

    trainloader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=64)
    validloader = torch.utils.data.DataLoader(train_data, sampler=valid_sampler, batch_size=64)
    testloader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=False)

    return trainloader, validloader, testloader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = MiniVGG_DropoutBeforeFC().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainloader, validloader, testloader = load_split_train_test('./data', valid_size=0.1)


def train(n_epochs, patience_limit):
    valid_loss_min = np.Inf
    patience = 0  # Counter for the number of epochs without improvement
    train_losses, valid_losses = [], []
    train_accuracies, valid_accuracies = [], []
    
    for epoch in range(1, n_epochs+1):
        train_loss = 0.0
        valid_loss = 0.0
        correct = 0
        total = 0
        
        net.train()
        for data, target in trainloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = net(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * data.size(0)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
        train_accuracy = 100 * correct / total
        train_losses.append(train_loss / len(trainloader.sampler))
        train_accuracies.append(train_accuracy)
        
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in validloader:
                data, target = data.to(device), target.to(device)
                output = net(data)
                loss = criterion(output, target)
                valid_loss += loss.item() * data.size(0)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
                
        valid_accuracy = 100 * correct / total
        valid_losses.append(valid_loss / len(validloader.sampler))
        valid_accuracies.append(valid_accuracy)
        
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tTraining Accuracy: {:.2f}% \tValidation Accuracy: {:.2f}%'.format(
            epoch, train_loss / len(trainloader.sampler), valid_loss / len(validloader.sampler),
            train_accuracy, valid_accuracy))
        
        # Check if the validation loss has decreased
        if valid_loss < valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(net.state_dict(), 'model_cifar.pt')
            valid_loss_min = valid_loss
            patience = 0  # Reset patience since we have an improvement
        else:
            patience += 1  # Increment the patience counter
            print(f'Patience for {patience} epochs.')
            if patience >= patience_limit:
                print('Early stopping triggered.')
                break
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# Example usage
patience_limit = 5  # Number of epochs to tolerate no improvement
train_losses, valid_losses, train_accuracies, valid_accuracies = train(50, patience_limit)


# Plotting the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# Test the model with test data
def test():
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))

test()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1 	Training Loss: 1.495351 	Validation Loss: 1.242430 	Training Accuracy: 45.04% 	Validation Accuracy: 54.66%
# Validation loss decreased (inf --> 6212.151505). Saving model ...
# Epoch: 2 	Training Loss: 1.127768 	Validation Loss: 0.991716 	Training Accuracy: 59.96% 	Validation Accuracy: 64.22%
# Validation loss decreased (6212.151505 --> 4958.579755). Saving model ...
# Epoch: 3 	Training Loss: 0.969837 	Validation Loss: 1.039370 	Training Accuracy: 65.76% 	Validation Accuracy: 63.54%
# Patience for 1 epochs.
# Epoch: 4 	Training Loss: 0.883553 	Validation Loss: 0.804996 	Training Accuracy: 69.47% 	Validation Accuracy: 71.58%
# Validation loss decreased (4958.579755 --> 4024.981947). Saving model ...
# Epoch: 5 	Training Loss: 0.814175 	Validation Loss: 0.858989 	Training Accuracy: 71.60% 	Validation Accuracy: 70.58%
# Patience for 1 epochs.
# Epoch: 6 	Training Loss: 0.758016 	Validation Loss: 0.717757 	Training Accuracy: 73.86% 	Validation Accuracy: 75.24%
# Validation loss decreased (4024.981947 --> 3588.783315). Saving model ...
# Epoch: 7 	Training Loss: 0.711951 	Validation Loss: 0.651252 	Training Accuracy: 75.36% 	Validation Accuracy: 77.60%
# Validation loss decreased (3588.783315 --> 3256.261280). Saving model ...
# Epoch: 8 	Training Loss: 0.667653 	Validation Loss: 0.646244 	Training Accuracy: 76.85% 	Validation Accuracy: 77.04%
# Validation loss decreased (3256.261280 --> 3231.219584). Saving model ...
